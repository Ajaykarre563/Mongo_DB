# %% [markdown]
# # **projection operators are used to specify which fields to include or exclude in query results.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **elematch**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# db.products.insertMany([
#   {
#     name: 'iPhone 15 Pro Max',
#     brand: 'Apple',
#     price: 1299,
#     reviews: ["Great", "Expensive", "Fast", "Camera is amazing", "Battery life is okay"]
#   },
#   {
#     name: 'Galaxy S24 Ultra',
#     brand: 'Samsung',
#     price: 1199,
#     reviews: ["Brilliant display", "Overheats sometimes", "Smooth performance", "Excellent camera"]
#   },
#   {
#     name: 'PlayStation 5',
#     brand: 'Sony',
#     price: 499,
#     reviews: ["Next-gen gaming", "Huge design", "Fast loading", "Good controller", "Limited stock"]
#   },
#   {
#     name: 'MacBook Air M2',
#     brand: 'Apple',
#     price: 999,
#     reviews: ["Lightweight", "Silent", "Powerful", "Great battery life", "Expensive"]
#   },
#   {
#     name: 'Nintendo Switch OLED',
#     brand: 'Nintendo',
#     price: 349,
#     reviews: ["Vibrant screen", "Family fun", "Better battery", "Joy-Con drift issues"]
#   },
#   {
#     name: 'OnePlus 12',
#     brand: 'OnePlus',
#     price: 799,
#     reviews: ["Fast charging", "Value for money", "Clean UI", "Heats under load"]
#   },
#   {
#     name: 'iPad Pro 12.9',
#     brand: 'Apple',
#     price: 1099,
#     reviews: ["Amazing display", "Pricey", "Great for drawing", "No headphone jack"]
#   },
#   {
#     name: 'Dell XPS 13',
#     brand: 'Dell',
#     price: 899,
#     reviews: ["Sleek design", "Sharp screen", "Keyboard is cramped", "Good for work"]
#   },
#   {
#     name: 'Google Pixel 8 Pro',
#     brand: 'Google',
#     price: 999,
#     reviews: ["Pure Android", "Excellent camera", "Battery could be better", "Tensor chip is unique"]
#   },
#   {
#     name: 'Sony WH-1000XM5',
#     brand: 'Sony',
#     price: 399,
#     reviews: ["Best noise cancellation", "Comfortable", "Great sound", "Touch controls are finicky"]
#   }
# ])
#
# ```

# %% [markdown]
# ```
# db.products.find(
#   {},  // no filter, get all documents
#   {
#     name: 1,
#     reviews: { $slice: -2 },
#     _id: 0
#   }
# )
#
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)
