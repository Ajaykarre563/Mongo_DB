# %% [markdown]
# # **Updating User Role**

# %% [markdown]
# ```
# db.updateUser("john", {
#   roles: [
#     { role: "readWrite", db: "eShopping" },
#     { role: "readWrite", db: "sample" }
#   ]
# })
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
