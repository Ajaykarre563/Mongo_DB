# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **next() method:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **forEach() method:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **hasNext() method**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **sorting:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **you can see different when 2 persons having same name but different ages**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
