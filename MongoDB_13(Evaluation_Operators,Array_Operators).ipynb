# %% [markdown]
# # **✅ MongoDB Evaluation Operators**
# Evaluation operators in MongoDB are used to perform conditional logic and expression-based filtering in queries. They allow for more dynamic and flexible querying beyond just field-value matching.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# db.products.find({
#   $expr: {
#     $gt: [
#       { $subtract: ["$price", "$discount"] },
#       1000
#     ]
#   }
# })
#
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **✅ MongoDB Array Operators**
# Array operators allow you to query and manipulate array fields in MongoDB documents. They're powerful tools for working with embedded data like lists or subdocuments.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Note:**
# The order of elements in an array (like ["music", "cooking"] or ["cooking", "music"]) does n't matters in exact match queries, but not when using array-specific operators like **all**.

# %% [markdown]
# ![Screenshot 2025-05-16 125549.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **🔍Why use elemMatch?**
# Without $elemMatch, MongoDB would match any document where:
#
# One skill has name: "designer"
#
# And some other skill (not necessarily the same) has level: 3.
#
# Let me know if you’d like to search for ranges like level >= 3, or match multiple skills!

# %% [markdown]
# ![image.png](data:image/png;base64,...)
