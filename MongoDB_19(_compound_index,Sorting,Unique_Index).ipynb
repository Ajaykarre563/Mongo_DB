# %% [markdown]
# # **compound index?**(create 2 indexes)

# %% [markdown]
# **In MongoDB, a compound index is an index on multiple fields within a document. It helps improve the performance of queries that filter, sort, or both, on those fields.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **🔍 Index for Sorting in MongoDB**
# Indexes in MongoDB improve performance for sorting operations using .sort() if the sort order matches the index order.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **🔐 Unique Index in MongoDB**
# A unique index ensures that no two documents in a collection have the same value for the indexed field(s).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
